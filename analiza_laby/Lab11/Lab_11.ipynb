# %% [markdown]
# # Laboratoria 11
#
# Zadania oznaczone jako __Zadanie domowe__ zostaną sprawdzone podczas kolejnych laboratoriów i będą podlegały ocenie.

# %%
import matplotlib.pyplot as plt
import numpy as np
from typing import Callable

def draw_parametric(I: np.array, x: Callable[[np.ndarray], np.ndarray], y: Callable[[np.ndarray], np.ndarray]):
	t = np.linspace(I[0], I[1], 1000)
	X = x(t)
	Y = y(t)

	plt.figure(figsize=(6, 6))
	plt.plot(X, Y)
	
	max_range = max(
    np.max(X) - np.min(X),
    np.max(Y) - np.min(Y)
	) / 2
	x_mid = (np.max(X) + np.min(X)) / 2
	y_mid = (np.max(Y) + np.min(Y)) / 2
	plt.xlim(x_mid - max_range, x_mid + max_range)
	plt.ylim(y_mid - max_range, y_mid + max_range)
	
	plt.xlabel("x(t)")
	plt.ylabel("y(t)")
	plt.grid(True)
	plt.show()

# draw_parametric(
# 	[0, 2*np.pi],
# 	lambda t: np.cos(t),
# 	lambda t: np.sin(t)
# )

# %% [markdown]
# ## Całka krzywoliniowa niezorientowana i  całka krzywoliniowa zorientowana: part 1

# %% [markdown]
# ## Krzywe i ich parametryzacje

# %% [markdown]
# __Definicja.__ Krzywą $\gamma$ w przestrzeni  $\mathbb{R}^{n}$ nazywamy dowolny ciągły obraz odcinka $I=[a,b]$. Funkcję ciągłą $c\colon I\to\mathbb{R}^n$ nazywamy parametryzacją krzywej $\gamma$, o ile $\gamma = c(I)$.

# %% [markdown]
# ### Przykłady: parametryzowanie odcinka
#
# 1. Funkcja $c:[0,2]\to\mathbb{R}^2$ o wzorze
# $$
# c(t)=(t,2t)
# $$
# jest parametryzacją odcinka łączącego punkt $(0,0)$ z punktem $(2,4)$.
#
# 2. Funkcja $c:[0,1]\to\mathbb{R}^2$
#    o wzorze
# $$
# c(t)=(2t,4t)
# $$
# jest parametryzacją odcinka łączącego punkt $(0,0)$ z punktem $(2,4)$.
#
# 3. Funkcja $c:[-1,3]\to\mathbb{R}^2$ o wzorze
# $$
# c(t)=(-t,t+1)
# $$
# jest parametryzacją odcinka łączącego punkt $(1,0)$ z punktem $(-3,4)$.

# %% [markdown]
# __Uwaga:__ przykłady 1 oraz 2 pokazują,  że dana krzywa ma wiele różnych parametryzacji.

# %% [markdown]
# #### Zadanie domowe 1
# Podaj przykład parametryzacji odcinka łączącego:
#
# a) punkt $(0,4)$ z punktem $(0,7)$;
#
# b) punkt $(1,1)$ z punktem $(-3,1)$;
#
# c) punkt $(2,1)$ z punktem $(4,3)$.

# %% [markdown]
# a)
# $$
# c(t) = (0, 4 + t) \land I = [0, 3] \implies c(0) = (0, 4) \land c(3) = (0, 7)
# $$
#
# b)
# $$
# c(t) = (1 - t, 1) \land I = [0, 4] \implies c(0) = (1, 1) \land c(4) = (-3, 1)
# $$
#
# $$
#
# c)c(t) = (2 + t, 1 + t) \land I = [0, 2] \implies c(0) = (2, 1) \land c(2) = (4, 3)
# $$

# %%
draw_parametric(
	[0, 3],
	lambda t: np.sin(2*np.pi * t/3),
	lambda t: -t + 7 + np.sin(2*np.pi * t/3)
)

draw_parametric(
	[0, 4],
	lambda t: -3 + t + np.sin(2*np.pi * t/3),
	lambda t: 1 + np.sin(2*np.pi/3 * t/3)
)

# %% [markdown]
# ### Przykłady: parametryzowanie okręgu lub jego fragmentu

# %% [markdown]
# 1. Funkcja $c:[0,2\pi]\to\mathbb{R}^2$ o wzorze
# $$
# c(t)=(\cos t,\sin t )
# $$
# jest parametryzacją okręgu $x^2+y^2=1$: poruszamy się od punktu $(1,0)$ do punktu $(1,0)$ przeciwnie do wskazówek zegara.
#
# 2. Funkcja $c:[\pi/2,\pi]\to\mathbb{R}^2$ o wzorze
# $$
# c(t)=(2\cos t, 2\sin t )
# $$
# jest parametryzacją  fragmentu okręgu $x^2+y^2=4$: poruszamy się od punktu $(0,2)$ do punktu $(-2,0)$ przeciwnie do  wskazówek zegara.
#
# 3. Funkcja $c:[\pi,2\pi]\to\mathbb{R}^2$ o wzorze
# $$
# c(t)=(3\cos(-t), 3\sin(-t))=(3\cos t,-3\sin t)
# $$
# jest parametryzacją  fragmentu okręgu $x^2+y^2=9$: poruszamy się od punktu $(-3,0)$ do punktu $(3,0)$ zgodnie ze wskazówkami zegara.

# %% [markdown]
# #### Zadanie domowe 2
# a)  Podaj przykład parametryzacji fragmentu okręgu $x^2+y^2=\frac{1}{4}$: poruszamy się od punktu $(-1/2,0)$ do punktu
# $(1/2,0)$ przeciwnie do  wskazówek zegara.
#
# b)  Podaj przykład parametryzacji fragmentu okręgu $x^2+y^2=\frac{1}{4}$: poruszamy się od punktu $(-1/2,0)$ do punktu
# $(1/2,0)$ zgodnie ze wskazówkami zegara.
#
# c) Podaj przykład parametryzacji fragmentu okręgu $(x-1)^2+y^2=1$: poruszamy się od punktu $(1,1)$ do punktu
# $(1-\sqrt{2}/2,\sqrt{2}/2)$   przeciwnie do wskazówek zegara.

# %% [markdown]
# a)
# $$
# c(t) = (\frac{1}{2}\cos(t), \frac{1}{2}\sin(t)) \land I = [\pi, 2\pi] \implies
# c(\pi) = (\frac{1}{2}\cos(\pi), \frac{1}{2}\sin(\pi)) = (-\frac{1}{2}, 0) \land
# c(2\pi) = (\frac{1}{2}\cos(2\pi), \frac{1}{2}\sin(2\pi)) = (\frac{1}{2}, 0)
# $$
# Poruszamy się po dolnym półokręgu przeciwnie do wskazówek zegara.
#
# b)
# $$
# c(t) = (\frac{1}{2}\cos(-t), \frac{1}{2}\sin(-t)) = (\frac{1}{2}\cos(t), -\frac{1}{2}\sin(t)) \land I = [0, \pi] \implies
# c(0) = (\frac{1}{2}, 0) \land c(\pi) = (-\frac{1}{2}, 0)
# $$
# Poruszamy się po dolnym półokręgu zgodnie ze wskazówkami zegara (od (1/2,0) do (-1/2,0)).
#
#
#
# Alternatywnie: $c(t) = (\frac{1}{2}\cos(t), \frac{1}{2}\sin(t)) \land I = [0, -\pi]$ lub przejście przez górny półokrąg w przeciwnym kierunku.$$
#
# c(t) = (1 + \cos(t), \sin(t)) \land I = [\frac{\pi}{2}, \frac{3\pi}{4}]
#
# c)$$
#
# Okrąg $(x-1)^2 + y^2 = 1$ ma środek w $(1, 0)$ i promień $r = 1$.Punkt $(1-\sqrt{2}/2, \sqrt{2}/2)$ odpowiada kątowi $t = 3\pi/4$ (bo $1 + \cos(3\pi/4) = 1 - \sqrt{2}/2, \sin(3\pi/4) = \sqrt{2}/2$).
# Punkt $(1, 1)$ odpowiada kątowi $t = \pi/2$ (bo $1 + \cos(\pi/2) = 1, \sin(\pi/2) = 1$).

# %%
draw_parametric(
  [np.pi, 2*np.pi],
  lambda t: 1/2 * np.cos(t),
  lambda t: 1/2 * np.sin(t),
)

draw_parametric(
  [np.pi, 2*np.pi],
  lambda t: 1/2 * np.cos(-t),
  lambda t: 1/2 * np.sin(-t),
)

# %% [markdown]
# ### Przykłady: parametryzacja fragmentu wykresu funkcji

# %% [markdown]
# 1.  Funkcja $c:[0,1]\to\mathbb{R}^2$ o wzorze
# $$
# c(t)=(t,t^2)
# $$
# jest parametryzacją pewnej krzywej: poruszamy się po wykresie funkcji $y=x^2$ od punktu $(0,0)$ do punktu $(1,1)$.
#
# 2.  Funkcja $c:[1,2]\to\mathbb{R}^2$ o wzorze
# $$
# c(t)=(t,\sqrt{t+t^2})
# $$
# jest parametryzacją pewnej krzywej: poruszamy się po wykresie funkcji $y=\sqrt{x+x^2}$ od punktu $(1,\sqrt{2})$ do punktu $(2,\sqrt{6})$.

# %% [markdown]
# #### Zadanie domowe 3
#
# a) Niech funkcja $c:[a,b]\to\mathbb{R}^2$ będzie parametryzacją krzywej $\gamma$.
# Czego parametryzacją jest funkcja $c_1:[-b,-a]\to\mathbb{R}^2$ o wzorze $c_1(t)=c(-t)$?
#
# b) Niech funkcja $c:[0,4]\to\mathbb{R}^2$ będzie parametryzacją krzywej $\gamma$.
# Czego parametryzacją jest funkcja $c_1:[0,2]\to\mathbb{R}^2$ o wzorze $c_1(t)=c(2t)$?

# %% [markdown]
# a)
# Rysowanie funcki wstecz wymaga zmainy znaku przy t. $c(t) \implies c(-t)$ przez to wartości będą szły w drógą strone. Oraz zmiane $I$ na przeciwny znak oraz skoro $a \le b$ to po zmianie znaków mamy $ -b \le -a$. W ten sposoób zaczynamy od końca i poruszamy sie w strone początku.
#
# b)
# Możemy sprzężyć lub rozszerzyć funkcjie parametryczną po przez podzielenie $t$ przez $a$ i wymnożenie go w funkcji $c(t)$. Czyli $I = [\frac{a}{g}, \frac{b}{g}]$ oraz $c(gt)$. To nic nie zmienia w rysowaniu funkcji ponieważ t działa na $\mathbb{R}$ zatem gdy zwężymy przedział ale rozszerzymy funkcjie nic sie nie zmieni.

# %%
draw_parametric(
  [0, 1],
  lambda t: t,
  lambda t: t * t
)

print("a)")

draw_parametric(
  [-1, 0],
  lambda t: -t,
  lambda t: t * t
)

print("b)")

draw_parametric(
  [0, 1 * 2],
  lambda t: t / 2,
  lambda t: t * t / 4
)
# Out:
# a)
# b)

# %% [markdown]
# ## Długość krzywej

# %% [markdown]
# __Definicja.__ Niech $$\gamma:[a, b]\to\mathbb{R}^2,\quad \gamma(t)=(\gamma_1(t),\gamma_2(t))$$ będzie krzywą gładką (to oznacza z definicji, że
# funkcje $\gamma_1$ oraz $\gamma_2$ mają ciągłe pochodne). Długość krzywej $\gamma$ oznaczamy
# przez $L(\gamma)$ i definiujemy wzorem:
#
# $$
# L(\gamma) = \int_{a}^{b} |\gamma'(t)| dt=\int_a^b\sqrt{(\gamma_1'(t))^2+(\gamma_2'(t))^2}dt.
# $$

# %% [markdown]
# #### Zadanie domowe 4
#
# Oblicz długość poniższych krzywych:
#
# a) $\gamma:[0, 2]\to\mathbb{R}^2$, $\gamma(t)=(t,2-t)$;
#
# b)  $\gamma:[0, 2\pi]\to\mathbb{R}^2$, $\gamma(t)=(3\cos t ,3\sin t)$.

# %% [markdown]
# a)
# $$
# \int_{0}^{2}\sqrt{((t)')^{2} + ((2 - t)')^{2}}dt = \int_{0}^{2}\sqrt{1^{2} + (-1)^{2}}dt = \int_{0}^{2}\sqrt{1 + 1}dt = \int_{0}^{2}\sqrt{2}dt = [t\sqrt{2}]_{0}^{2} = 2\sqrt{2}
# $$
#
# b)
# $$
# \int_{0}^{2\pi}\sqrt{((3\cos(t))')^{2} + ((3\sin(t))')^{2}}dt = \int_{0}^{2\pi}\sqrt{(-3\sin(t))^{2} + (3\cos(t))^{2}}dt = \int_{0}^{2\pi}\sqrt{9\sin(t)^{2} + 9\cos(t)^{2}}dt = \int_{0}^{2\pi}3\sqrt{\sin(t)^{2} + \cos(t)^{2}}dt = \int_{0}^{2\pi}3\sqrt{1}dt = \int_{0}^{2\pi}3dt = [3t]_{0}^{2\pi} = 6\pi
# $$

# %%
import sympy as sp


print("a)")
t = sp.symbols('t')

expr = sp.sqrt(sp.diff((t), t)**2 + sp.diff((2 - t), t)**2)
print(sp.integrate(expr, (t, 0, 2)))
print()

print("b)")
t = sp.symbols('t')

expr = sp.sqrt(sp.diff((3*sp.cos(t)), t)**2 + sp.diff((3*sp.sin(t)), t)**2)
print(sp.integrate(expr, (t, 0, 2 * sp.pi)))
# Out:
# a)
# 2*sqrt(2)
#
# b)
# 6*pi

# %% [markdown]
# ## Całka krzywoliniowa niezorientowana (nieskierowana)
#
# __Definicja__
# Niech $$\gamma:[a, b]\to\mathbb{R}^2,\quad \gamma(t)=(\gamma_1(t),\gamma_2(t))$$ będzie krzywą gładką. Niech funkcja $f$ będzie funkcją ciągłą określoną na krzywej $\gamma$ (to jest na zbiorze $\gamma([a,b])$).
#
# Liczbę
#
# $$
# \int_a^bf(\gamma(t))\sqrt{(\gamma_1'(t))^2+(\gamma_2'(t))^2}dt
# $$
# nazywamy całką krzywoliniową niezorientowaną (nieskierowaną) z funkcji $f$ po  krzywej $\gamma$
# i oznaczamy symbolem
#
# $$
# \int_\gamma fds.
# $$

# %% [markdown]
# __Skąd nazwa?__
#
# Jeśli po krzywej będziemy się poruszali od końca do początku, to wartość całki się  nie zmieni.
#
# __Interpretacja fizyczna__
#
# __1.__ Jeśli niejednorodny pręt o kształcie $\gamma$ ma gęstość $f$, to $\int_\gamma fds$ to jego masa.
#
# __2.__ Jeśli funkcja $f$ jest nieujemna, to pole trapezu krzywoliniowego
#
# ![line5b.jpg](attachment:45d23b54-c44c-4b25-90d1-e83a6023d6d5.jpg)
#
# jest równe
# $\int_\gamma fds$.

# %% [markdown]
# ### Przykład
#
# Jeśli $\gamma:[0,1]\to\mathbb{R}^2$, $\gamma(t)=(3t,4t+1)$ a funkcja $f$ dana jest wzorem
# $f(x,y)=x^2+y$, to

# %% [markdown]
# $$
# \int_\gamma fds=\int_0^1f(\gamma(t))\sqrt{(\gamma_1'(t))^2+(\gamma_2'(t))^2}dt=
# \int_0^1f(3t,4t+1)\sqrt{3^2+4^2}dt=5\int_0^1(3t)^2+4t+1dt=30.
# $$

# %% [markdown]
# #### Zadanie domowe 5
# a) Wyprowadź wzór na pole powierzchni bocznej walca o promieniu podstawy $r$ i wysokości $h$.
#
# b) Oblicz $\int_{\gamma_1} fds$ oraz $\int_{\gamma_2} fds$, gdzie $f(x,y)=xy$,
# $\gamma_1:[0,4]\to\mathbb{R}^2$, $\gamma_1(t)=(t,2t)$ oraz $\gamma_2:[0,2]\to\mathbb{R}^2$, $\gamma_2(t)=(2t,4t)$.
# Co zauważasz? Skąd to wynika?

# %% [markdown]
# a)
# $$
# f(y_{1}(t), y_{2}(t)) = h
# $$
# $$
# \int_{0}^{2\pi}h\sqrt{((r\cos(t))')^2 + ((r\sin(t))')^2}dt =
# \int_{0}^{2\pi}h\sqrt{(-r\sin(t))^2 + (r\cos(t))^2}dt =
# \int_{0}^{2\pi}hr\sqrt{(\sin(t))^2 + (\cos(t))^2}dt =
# \int_{0}^{2\pi}hrdt = [thr]_{0}^{2\pi} =
# hr2\pi
# $$
#
# b)
# $$
# f(x, y) = xy
# $$
#
# 1)
# $$
# I = [0, 4] \land y_{1}(t) = (t, 2t)
# $$
# $$
# \int_{0}^{4} f(y_{1}(t))\sqrt{((t)')^{2} + ((2t)')^{2}}dt =
# \int_{0}^{4} 2t^{2}\sqrt{(1)^{2} + (2)^{2}}dt =
# \int_{0}^{4} 2t^{2}\sqrt{1 + 4}dt =
# \int_{0}^{4} 2t^{2}\sqrt{5}dt =
# [\frac{2}{3}t^{3}\sqrt{5}]_{0}^{4} = \frac{128}{3}\sqrt{5}
# $$
#
# $$
# I = [0, 2] \land y_{1}(t) = (2t, 4t)
# $$
# $$
# \int_{0}^{2} f(y_{1}(t))\sqrt{((2t)')^{2} + ((4t)')^{2}}dt =
# \int_{0}^{2} 8t^{2}\sqrt{(2)^{2} + (4)^{2}}dt =
# \int_{0}^{2} 8t^{2}\sqrt{4 + 16}dt =
# \int_{0}^{2} 8t^{2}\sqrt{20}dt =
# [\frac{16}{3}t^{3}\sqrt{5}]_{0}^{2} = \frac{128}{3}\sqrt{5}
# $$
#
# Wyniki są takie same bo jedyne co zmieniliśmy to zwężyliśmy przedział funkcjia tak na prawde sie nie zmieniła.

# %%
print("a)")

r = sp.symbols('r', positive=True)
h = sp.symbols('h', positive=True)
t = sp.symbols('t')

expr = h * sp.sqrt(sp.diff(r * sp.cos(t), t)**2 + sp.diff(r * sp.sin(t), t)**2)

print(sp.integrate(expr, (t, 0, 2*sp.pi)))
print()

print("b)")

t = sp.symbols('t')

expr = 2 * t**2 * sp.sqrt(sp.diff(t, t)**2 + sp.diff(2*t, t)**2)
print(sp.integrate(expr, (t, 0, 4)))
print()

expr = 8 * t**2 * sp.sqrt(sp.diff(2 * t, t)**2 + sp.diff(4 * t, t)**2)
print(sp.integrate(expr, (t, 0, 2)))
# Out:
# a)
# 2*pi*h*r
#
# b)
# 128*sqrt(5)/3
#
# 128*sqrt(5)/3

# %% [markdown]
# ## Całka krzywoliniowa zorientowana (skierowana)

# %% [markdown]
# __Przypomnienie:__
#
# Iloczynem skalarnym wektorów $\overrightarrow{a}=(a_1,a_2)$ oraz $\overrightarrow{b}=(b_1,b_2)$ nazywamy liczbę
# $$
# \overrightarrow{a}\cdot\overrightarrow{b}=a_1b_1+a_2b_2.
# $$
#
# __Interpretacja fizyczna:__
#
# Jeśli $\overrightarrow{F}$ jest wektorem siły a $\overrightarrow{d}$ jest wektorem przesunięcia, to liczba $\overrightarrow{F}\cdot \overrightarrow{d}$
# jest równa pracy wykonanej przy przesunięciu punktu materialnego o wektor $\overrightarrow{d}$ z użyciem siły $\overrightarrow{F}$.
#
# __Definicja całki krzywoliniowej zorientowanej__
#
# Niech $$\gamma:[a, b]\to\mathbb{R}^2,\quad \gamma(t)=(\gamma_1(t),\gamma_2(t))$$ będzie krzywą gładką.  Niech funkcja $F(x,y)=(P(x,y),Q(x,y))$ będzie funkcją ciągłą (o wartościach w $\mathbb{R}^2$) określoną na krzywej $\gamma$ (to jest na zbiorze $\gamma([a,b])$).
# Liczbę
#
# $$
# \int_a^bP(\gamma_1(t),\gamma_2(t))\gamma_1'(t)+Q(\gamma_1(t),\gamma_2(t))\gamma_2'(t)dt
# $$
# nazywamy całką krzywoliniową zorientowaną z pola wektorowego $F$ wzdłuż krzywej $\gamma$
# i
# oznaczamy symbolem
#
# $$
# \int_\gamma P(x,y)dx+Q(x,y)dy.
# $$
# __Obserwacja:__
# pod całką jest iloczyn skalarny wektorów $F(x,y)=(P(x,y),Q(x,y))$ i $(\gamma_1'(t),\gamma_2'(t))$.
#
# __Terminologia:__ funkcję $F$ nazywamy polem wektorowym.
#
# __Interpretacja fizyczna:__ całka krzywoliniowa, to praca jaką wykonujemy przesuwając punkt materialny wzdłuż krzywej $\gamma$ w polu elektrycznym lub grawitacyjnym $F$.

# %% [markdown]
# ### Przykład

# %% [markdown]
# Niech $\gamma:[0,1]\to\mathbb{R}^2$ będzie krzywą o wzorze $\gamma(t)=(t^2,t^3)$.
#
# 1. Obliczymy
#
# $$
# \int_\gamma xdx+ydy.
# $$
# __UWAGA!!!!:__  to jest banalne zadanie, po prostu trzeba podstawić do wzoru.
#
# Mamy:
# $$
# \int_\gamma xdx+ydy=\int_0^1t^2\cdot 2t+t^3\cdot3t^2dt=\ldots=1.
# $$

# %% [markdown]
# 2. Obliczymy
#
# $$
# \int_\gamma x+ydx.
# $$
#
# __UWAGA:__
#
# To co mamy policzyć, to skrócona forma od zapisu:
# $$
# \int_\gamma x+ydx+0dy.
# $$
# Mamy
# $$
# \int_\gamma x+ydx=\int_0^1(t^2+t^3)2tdt=\frac{9}{10}.
# $$

# %% [markdown]
# #### Zadanie domowe 6
# Niech $\gamma:[0,2\pi]\to\mathbb{R}^2$, $\gamma(t)=(cos(t),\sin(t))$.
# Oblicz
# $$
# \int_\gamma xdx+ydy
# $$
# Wytłumacz wynik podając fizyczną interpretację tego co się stało.

# %% [markdown]
# ### Rozwiązanie Zadania 6
#
# Mamy $\gamma(t) = (\cos(t), \sin(t))$ dla $t \in [0, 2\pi]$.
#
# Obliczamy pochodne: $\gamma_1'(t) = -\sin(t)$, $\gamma_2'(t) = \cos(t)$.
#
# Dla pola $P(x,y) = x$, $Q(x,y) = y$:
#
# $$
# \int_\gamma xdx + ydy = \int_0^{2\pi} \cos(t) \cdot (-\sin(t)) + \sin(t) \cdot \cos(t) \, dt
# $$
#
# $$
# = \int_0^{2\pi} (-\cos(t)\sin(t) + \sin(t)\cos(t)) \, dt = \int_0^{2\pi} 0 \, dt = 0
# $$
#
# **Interpretacja fizyczna:**
#
# Wynik równy 0 oznacza, że praca wykonana przy przesunięciu punktu materialnego wzdłuż zamkniętej krzywej (okręgu) w polu wektorowym $F(x,y) = (x, y)$ jest równa zeru.
#
# Pole $F(x,y) = (x, y)$ jest polem zachowawczym (potencjalnym) - pochodzi od potencjału $U(x,y) = \frac{1}{2}(x^2 + y^2)$, ponieważ $\nabla U = (x, y) = F$.
#
# W polach zachowawczych całka krzywoliniowa po zamkniętej krzywej jest zawsze równa zeru, ponieważ energia potencjalna na początku i na końcu ścieżki jest taka sama (wracamy do punktu wyjścia).
